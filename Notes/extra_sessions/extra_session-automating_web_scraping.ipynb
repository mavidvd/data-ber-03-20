# %%
import pandas as pd
import datetime
import re
import requests
import bs4

# %% [markdown]
# # Web Scraping - Build little functions

# %% [markdown]
# ### I. Get suppe

# %%
def get_suppe(url):
    resp = requests.get(url)
    return bs4.BeautifulSoup(resp.content, "html.parser")

# %%
url = "https://www.coursereport.com/best-coding-bootcamps"
suppe = get_suppe(url)

# %% [markdown]
# ### II. Get list of school items

# %%
def get_school_list(soup):
    return (soup
            .find("ul", id="schools")
            .find_all("li"))

# %%
school_list = get_school_list(suppe)

# %%
sample = school_list[14]

# %% [markdown]
# ### III. For each school, extract
#
# #### 1. rank and name

# %%
def get_rank(school_item):
    rank_pattern = r"^(\d{1,2})\."
    rank = (school_item
            .find("h3")
            .find("a")
            .text)
    return int(re.findall(rank_pattern, rank)[0])

def get_name(school_item):
    name_pattern = r"^\d{1,2}\.\s(.+)"
    name = (school_item
            .find("h3")
            .find("a")
            .text)
    return re.findall(name_pattern, name)[0]

# %%
get_rank(sample)
# Out:
# 15

# %%
get_name(sample)
# Out:
# 'Ironhack'

# %% [markdown]
# #### 2. Get rating

# %%
def get_rating(school_item):
    rating_pattern = r"\((.+)\)"
    rating = (school_item
              .find("span",
                    class_="longform-rating-text")
              .text)
    
    return float(re.findall(rating_pattern, rating)[0])

# %%
get_rating(sample)
# Out:
# 4.88

# %% [markdown]
# #### 3. Get no of reviews

# %%
def get_reviews(school_item):
    reviews_pattern = r"(^\d*)\s"
    reviews = (school_item
               .find_all("span",
                         class_="longform-rating-text")[1]
               .find("a")
               .text)
    return int(re.findall(reviews_pattern, reviews)[0])

# %%
get_reviews(sample)
# Out:
# 903

# %% [markdown]
# #### 4. Get Locations

# %% [markdown]
# ---

# %%
"|".join(["A", "2", "c"])
# Out:
# 'A|2|c'

# %%
pd.DataFrame([{"columnA": 12,
               "columnB": "ABC",
               "columnC": "|".join(["A", "2", "c"])}])
# Out:
#    columnA columnB columnC
# 0       12     ABC   A|2|c

# %% [markdown]
# ---

# %%
def get_locations(school_item):
    location_list = (school_item
                     .find("span",
                           class_="location")
                     .find_all("a"))
    return "|".join([loc.text for loc in location_list])

# %%
get_locations(sample)
# Out:
# 'Miami|Madrid|Mexico City|Paris|Berlin|Amsterdam|Sao Paulo|Lisbon|Barcelona'

# %% [markdown]
# #### 5. Get description

# %%
def get_description(school_item):
    return (school_item
            .find("div",
                  class_="desc-container")
            .find_all("p"))[1].text

# %%
get_description(sample)
# Out:
# 'Ironhack offers 9-week, full-time and 24-week, part-time bootcamps in web development, UX/UI design, and data analytics in Miami (Florida), Madrid and Barcelona (Spain), Paris (France) Mexico\xa0City (Mexico), Berlin (Germany), Amsterdam (Netherlands),\xa0Sao Paulo (Brazil) and Lisbon (Portugal).\xa0Ironhack uses a customized approach to education by allowing students to shape their experience based on personal goals. Students who graduate from the Web Development Bootcamp will be skilled in technologies like\xa0JavaScript, HTML5 and CSS3.\xa0The UX/UI program covers Design Thinking, Photoshop, Sketch, Balsamiq, InVision, and JavaScript.\xa0Data Analytics covers data wrangling/cleaning, APIs, web scraping, and intermediate topics in Git, MySQL,\xa0Python, Data visualization, Panda, and Machine Learning. And the Data Analytics program allows students to load, clean, explore and extract valuable insights from datasets and cultivate languages scuh as Python, SQL and Tableau.\xa0 '

# %%
def get_stars(school_item):
    stars_dict = {"icon-full_star": 1,
                  "icon-half_star": .5,
                  "icon-empty_star": 0}
    stars = (school_item
             .find("div",
                   class_="ratings title-rating")
             .find_all("span"))[1:]
    
    return float(sum([stars_dict[star["class"][0]] for star in stars]))

# %%
get_stars(sample)
# Out:
# 5.0

# %% [markdown]
# ### IV. Create a function that processes one school_item

# %%
def get_record(school_item):
    return {"rank": get_rank(school_item),
            "name": get_name(school_item),
            "rating": get_rating(school_item),
            "stars": get_stars(school_item),
            "reviews": get_reviews(school_item),
            "locations": get_locations(school_item),
            "description": get_description(school_item)}

# %%
get_record(sample)
# Out:
# {'rank': 15,
#  'name': 'Ironhack',
#  'rating': 4.88,
#  'stars': 5.0,
#  'reviews': 903,
#  'locations': 'Miami|Madrid|Mexico City|Paris|Berlin|Amsterdam|Sao Paulo|Lisbon|Barcelona',
#  'description': 'Ironhack offers 9-week, full-time and 24-week, part-time bootcamps in web development, UX/UI design, and data analytics in Miami (Florida), Madrid and Barcelona (Spain), Paris (France) Mexico\xa0City (Mexico), Berlin (Germany), Amsterdam (Netherlands),\xa0Sao Paulo (Brazil) and Lisbon (Portugal).\xa0Ironhack uses a customized approach to education by allowing students to shape their experience based on personal goals. Students who graduate from the Web Development Bootcamp will be skilled in technologies like\xa0JavaScript, HTML5 and CSS3.\xa0The UX/UI program covers Design Thinking, Photoshop, Sketch, Balsamiq, InVision, and JavaScript.\xa0Data Analytics covers data wrangling/cleaning, APIs, web scraping, and intermediate topics in Git, MySQL,\xa0Python, Data visualization, Panda, and Machine Learning. And the Data Analytics program allows students to load, clean, explore and extract valuable insights from datasets and cultivate languages scuh as Python, SQL and Tableau.\xa0 '}

# %% [markdown]
# ### V. Process all schools

# %%
school_ranking = [get_record(school) for school in school_list]

# %%
df = pd.DataFrame(school_ranking)

# %%
df
# Out:
#     rank                        name  rating  stars  reviews  \
# 0      1             Flatiron School    4.71    4.5      439
# 1      2                Hack Reactor    4.70    4.5      274
# 2      3                   Codesmith    4.90    5.0      358
# 3      4                 App Academy    4.68    4.5      826
# 4      5                      Turing    4.77    4.5      159
# 5      6           Fullstack Academy    4.89    5.0      270
# 6      7            General Assembly    4.32    4.5      452
# 7      8               Tech Elevator    4.95    5.0      217
# 8      9               DigitalCrafts    4.88    5.0      210
# 9     10              Software Guild    4.66    4.5      146
# 10    11            Holberton School    4.46    4.5       79
# 11    12                     Wyncode    4.74    4.5      296
# 12    13                BrainStation    4.68    4.5      352
# 13    14                 Devmountain    4.60    4.5      279
# 14    15                    Ironhack    4.88    5.0      903
# 15    16                       Sabio    4.85    5.0      195
# 16    17          Hackbright Academy    4.54    4.5       79
# 17    18                    Le Wagon    4.99    5.0     1513
# 18    19                    Epicodus    4.71    4.5      156
# 19    20                 Coding Dojo    4.43    4.5      433
# 20    21             Lighthouse Labs    4.45    4.5       92
# 21    22               DevPoint Labs    4.86    5.0      138
# 22    23               Coder Academy    4.74    4.5      101
# 23    24                Rithm School    4.98    5.0       48
# 24    25        Grace Hopper Program    4.91    5.0       46
# 25    26                LearningFuze    4.99    5.0      168
# 26    27               Coding Temple    4.91    5.0      120
# 27    28              Makers Academy    4.81    5.0      183
# 28    29         Zip Code Wilmington    4.98    5.0       63
# 29    30        Eleven Fifty Academy    4.70    4.5       63
# 30    31              Launch Academy    4.60    4.5       47
# 31    32              SPICED Academy    4.70    4.5       57
# 32    33                    V School    4.78    4.5       52
# 33    34           Tech Talent South    4.73    4.5       99
# 34    35                Code Fellows    4.20    4.0      124
# 35    36            Skill Distillery    4.57    4.5       82
# 36    37              We Can Code IT    4.63    4.5       70
# 37    38                   Actualize    4.88    5.0      234
# 38    39                Code Platoon    4.96    5.0       45
# 39    40       Prime Digital Academy    4.86    5.0       88
# 40    41         Concordia Bootcamps    4.72    4.5       69
# 41    42               Claim Academy    4.53    4.5      117
# 42    43                 RED Academy    4.47    4.5       64
# 43    44               Coder Foundry    4.65    4.5       88
# 44    45            The Tech Academy    4.83    5.0      227
# 45    46  Juno College of Technology    4.98    5.0      207
# 46    47                 devCodeCamp    4.73    4.5      102
# 47    48       Skylab Coders Academy    4.98    5.0       64
#
#                                             locations  \
# 0   Brooklyn|Houston|Washington|Chicago|San Franci...
# 1   San Francisco|Online|Austin|Los Angeles|New Yo...
# 2                    Online|Los Angeles|New York City
# 3                  San Francisco|Online|New York City
# 4                                              Denver
# 5   Jacksonville|San Diego|San Luis Obispo|Baton R...
# 6   Orlando|Houston|Detroit|Raleigh|London|Singapo...
# 7   Cincinnati|Pittsburgh|Philadelphia|Cleveland|C...
# 8             Kennesaw|Houston|Atlanta|Online|Seattle
# 9               Louisville|Atlanta|Minneapolis|Online
# 10  Bogotá|Medellín|New Haven|Tunis|Cali|Tulsa|Bei...
# 11                                              Miami
# 12             Vancouver|Toronto|Online|New York City
# 13                        Lehi|Dallas|Atlanta|Phoenix
# 14  Miami|Madrid|Mexico City|Paris|Berlin|Amsterda...
# 15         Orange County|Riverside|Online|Los Angeles
# 16                                      San Francisco
# 17  Brussels|Bordeaux|Lille|Copenhagen|London|Rio ...
# 18                            Portland|Online|Seattle
# 19  Boise|Silicon Valley|Arlington|Tulsa|Dallas|Ch...
# 20  Calgary|Victoria|Ottawa|Vancouver|Toronto|Mont...
# 21                           Salt Lake City|Las Vegas
# 22                          Melbourne|Sydney|Brisbane
# 23                                      San Francisco
# 24                              Chicago|New York City
# 25                        Irvine|Orange County|Online
# 26            Washington|Boston|Dallas|Chicago|Online
# 27                                             London
# 28                                         Wilmington
# 29           Indianapolis|Hybrid (Online & In-person)
# 30                                             Boston
# 31                             Hamburg|Cologne|Berlin
# 32                                     Salt Lake City
# 33  Asheville|Charlotte|New Orleans|Columbus|San A...
# 34                                     Online|Seattle
# 35                                             Denver
# 36                                 Cleveland|Columbus
# 37                                     Chicago|Online
# 38                                            Chicago
# 39                            Kansas City|Minneapolis
# 40                                           Montreal
# 41                                          St. Louis
# 42                          Edmonton|Vancouver|London
# 43                                         Greensboro
# 44      Portland|Salt Lake City|Online|Denver|Seattle
# 45                                            Toronto
# 46                                          Milwaukee
# 47                                          Barcelona
#
#                                           description
# 0   Flatiron School offers immersive on-campus and...
# 1   Founded in 2012, Hack Reactor is a 12-week imm...
# 2   Codesmith offers a full-time, 12-week full sta...
# 3   App Academy offers immersive web development c...
# 4   Turing School of Software & Design is a 7-mont...
# 5   Fullstack Academy offers full-time and part-ti...
# 6   General Assembly offers short and long courses...
# 7   Tech Elevator is an immersive 14-week coding b...
# 8   DigitalCrafts offers a 16-week full-time and a...
# 9   The Software Guild offers immersive full-time,...
# 10  Holberton School is a two-year software engine...
# 11  Wyncode offers full-time and part-time full st...
# 12  BrainStation offers full-time and part-time co...
# 13  Devmountain is a technology school that offers...
# 14  Ironhack offers 9-week, full-time and 24-week,...
# 15  Sabio is a developer community offering 12-wee...
# 16  Hackbright Academy is a software engineering s...
# 17  Le Wagon offers 9-week full-time and 24-week p...
# 18  Epicodus is a coding bootcamp offering part- a...
# 19  Coding Dojo is a unique coding bootcamp that t...
# 20  Lighthouse Labs is a Canadian bootcamp that te...
# 21  DevPoint Labs teaches 11-week full-time and 11...
# 22  Coder Academy is an accredited Australian codi...
# 23  Rithm School offers a full-time, 16-week, full...
# 24  The Grace Hopper Program is a 17-week, immersi...
# 25  LearningFuze offers a full immersion, 12-week ...
# 26  Coding Temple offers 10-week, full-stack codin...
# 27  Makers Academy is a highly selective 4-month, ...
# 28  Zip Code Wilmington offers two full-time, 12-w...
# 29  Eleven Fifty Academy is a non-profit coding an...
# 30  Launch Academy is a full-time, 18-week program...
# 31  SPICED Academy offers full-time, 12-week codin...
# 32  V School is a technology school in Provo and S...
# 33  Tech Talent South offers full and part-time pr...
# 34  Code Fellows offers full and part-time softwar...
# 35  Skill Distillery is an intensive, 16-week Java...
# 36  We Can Code IT is a full-stack software develo...
# 37  Actualize is a 12-week software development bo...
# 38  Code Platoon is a non-profit coding bootcamp l...
# 39  Prime Digital Academy offers an intensive, 20-...
# 40  Concordia Bootcamps offers a 12-week, full-tim...
# 41  Claim Academy is a 3-month developer coding an...
# 42  RED Academy is a full-time, 12-week or 24-week...
# 43  Coder Foundry is a North Carolina coding bootc...
# 44  The Tech Academy offers 5 full-time and part-t...
# 45  Juno College of Technology offers a 9-week, fu...
# 46  devCodeCamp delivers a choice of programs focu...
# 47  Skylab Coders Academy in Barcelona, Spain, off...

# %% [markdown]
# ### VI. Adjusting the functions to account for the date the data was pulled

# %%
print(datetime.date.today())
# Out:
# 2020-05-13

# %%
def get_record(school_item, bootcamp_type, date=datetime.date.today()):
    return {"date_id": date,
            "bootcamp_type": bootcamp_type,
            "rank": get_rank(school_item),
            "name": get_name(school_item),
            "rating": get_rating(school_item),
            "stars": get_stars(school_item),
            "reviews": get_reviews(school_item),
            "locations": get_locations(school_item),
            "description": get_description(school_item)}

# %%
def get_rankings(school_list, bootcamp_type, date=datetime.date.today()):
    return pd.DataFrame([get_record(school, bootcamp_type, date) for school in school_list])

# %%
get_rankings(school_list, "coding")
# Out:
#        date_id bootcamp_type  rank                        name  rating  stars  \
# 0   2020-05-13        coding     1             Flatiron School    4.71    4.5
# 1   2020-05-13        coding     2                Hack Reactor    4.70    4.5
# 2   2020-05-13        coding     3                   Codesmith    4.90    5.0
# 3   2020-05-13        coding     4                 App Academy    4.68    4.5
# 4   2020-05-13        coding     5                      Turing    4.77    4.5
# 5   2020-05-13        coding     6           Fullstack Academy    4.89    5.0
# 6   2020-05-13        coding     7            General Assembly    4.32    4.5
# 7   2020-05-13        coding     8               Tech Elevator    4.95    5.0
# 8   2020-05-13        coding     9               DigitalCrafts    4.88    5.0
# 9   2020-05-13        coding    10              Software Guild    4.66    4.5
# 10  2020-05-13        coding    11            Holberton School    4.46    4.5
# 11  2020-05-13        coding    12                     Wyncode    4.74    4.5
# 12  2020-05-13        coding    13                BrainStation    4.68    4.5
# 13  2020-05-13        coding    14                 Devmountain    4.60    4.5
# 14  2020-05-13        coding    15                    Ironhack    4.88    5.0
# 15  2020-05-13        coding    16                       Sabio    4.85    5.0
# 16  2020-05-13        coding    17          Hackbright Academy    4.54    4.5
# 17  2020-05-13        coding    18                    Le Wagon    4.99    5.0
# 18  2020-05-13        coding    19                    Epicodus    4.71    4.5
# 19  2020-05-13        coding    20                 Coding Dojo    4.43    4.5
# 20  2020-05-13        coding    21             Lighthouse Labs    4.45    4.5
# 21  2020-05-13        coding    22               DevPoint Labs    4.86    5.0
# 22  2020-05-13        coding    23               Coder Academy    4.74    4.5
# 23  2020-05-13        coding    24                Rithm School    4.98    5.0
# 24  2020-05-13        coding    25        Grace Hopper Program    4.91    5.0
# 25  2020-05-13        coding    26                LearningFuze    4.99    5.0
# 26  2020-05-13        coding    27               Coding Temple    4.91    5.0
# 27  2020-05-13        coding    28              Makers Academy    4.81    5.0
# 28  2020-05-13        coding    29         Zip Code Wilmington    4.98    5.0
# 29  2020-05-13        coding    30        Eleven Fifty Academy    4.70    4.5
# 30  2020-05-13        coding    31              Launch Academy    4.60    4.5
# 31  2020-05-13        coding    32              SPICED Academy    4.70    4.5
# 32  2020-05-13        coding    33                    V School    4.78    4.5
# 33  2020-05-13        coding    34           Tech Talent South    4.73    4.5
# 34  2020-05-13        coding    35                Code Fellows    4.20    4.0
# 35  2020-05-13        coding    36            Skill Distillery    4.57    4.5
# 36  2020-05-13        coding    37              We Can Code IT    4.63    4.5
# 37  2020-05-13        coding    38                   Actualize    4.88    5.0
# 38  2020-05-13        coding    39                Code Platoon    4.96    5.0
# 39  2020-05-13        coding    40       Prime Digital Academy    4.86    5.0
# 40  2020-05-13        coding    41         Concordia Bootcamps    4.72    4.5
# 41  2020-05-13        coding    42               Claim Academy    4.53    4.5
# 42  2020-05-13        coding    43                 RED Academy    4.47    4.5
# 43  2020-05-13        coding    44               Coder Foundry    4.65    4.5
# 44  2020-05-13        coding    45            The Tech Academy    4.83    5.0
# 45  2020-05-13        coding    46  Juno College of Technology    4.98    5.0
# 46  2020-05-13        coding    47                 devCodeCamp    4.73    4.5
# 47  2020-05-13        coding    48       Skylab Coders Academy    4.98    5.0
#
#     reviews                                          locations  \
# 0       439  Brooklyn|Houston|Washington|Chicago|San Franci...
# 1       274  San Francisco|Online|Austin|Los Angeles|New Yo...
# 2       358                   Online|Los Angeles|New York City
# 3       826                 San Francisco|Online|New York City
# 4       159                                             Denver
# 5       270  Jacksonville|San Diego|San Luis Obispo|Baton R...
# 6       452  Orlando|Houston|Detroit|Raleigh|London|Singapo...
# 7       217  Cincinnati|Pittsburgh|Philadelphia|Cleveland|C...
# 8       210            Kennesaw|Houston|Atlanta|Online|Seattle
# 9       146              Louisville|Atlanta|Minneapolis|Online
# 10       79  Bogotá|Medellín|New Haven|Tunis|Cali|Tulsa|Bei...
# 11      296                                              Miami
# 12      352             Vancouver|Toronto|Online|New York City
# 13      279                        Lehi|Dallas|Atlanta|Phoenix
# 14      903  Miami|Madrid|Mexico City|Paris|Berlin|Amsterda...
# 15      195         Orange County|Riverside|Online|Los Angeles
# 16       79                                      San Francisco
# 17     1513  Brussels|Bordeaux|Lille|Copenhagen|London|Rio ...
# 18      156                            Portland|Online|Seattle
# 19      433  Boise|Silicon Valley|Arlington|Tulsa|Dallas|Ch...
# 20       92  Calgary|Victoria|Ottawa|Vancouver|Toronto|Mont...
# 21      138                           Salt Lake City|Las Vegas
# 22      101                          Melbourne|Sydney|Brisbane
# 23       48                                      San Francisco
# 24       46                              Chicago|New York City
# 25      168                        Irvine|Orange County|Online
# 26      120            Washington|Boston|Dallas|Chicago|Online
# 27      183                                             London
# 28       63                                         Wilmington
# 29       63           Indianapolis|Hybrid (Online & In-person)
# 30       47                                             Boston
# 31       57                             Hamburg|Cologne|Berlin
# 32       52                                     Salt Lake City
# 33       99  Asheville|Charlotte|New Orleans|Columbus|San A...
# 34      124                                     Online|Seattle
# 35       82                                             Denver
# 36       70                                 Cleveland|Columbus
# 37      234                                     Chicago|Online
# 38       45                                            Chicago
# 39       88                            Kansas City|Minneapolis
# 40       69                                           Montreal
# 41      117                                          St. Louis
# 42       64                          Edmonton|Vancouver|London
# 43       88                                         Greensboro
# 44      227      Portland|Salt Lake City|Online|Denver|Seattle
# 45      207                                            Toronto
# 46      102                                          Milwaukee
# 47       64                                          Barcelona
#
#                                           description
# 0   Flatiron School offers immersive on-campus and...
# 1   Founded in 2012, Hack Reactor is a 12-week imm...
# 2   Codesmith offers a full-time, 12-week full sta...
# 3   App Academy offers immersive web development c...
# 4   Turing School of Software & Design is a 7-mont...
# 5   Fullstack Academy offers full-time and part-ti...
# 6   General Assembly offers short and long courses...
# 7   Tech Elevator is an immersive 14-week coding b...
# 8   DigitalCrafts offers a 16-week full-time and a...
# 9   The Software Guild offers immersive full-time,...
# 10  Holberton School is a two-year software engine...
# 11  Wyncode offers full-time and part-time full st...
# 12  BrainStation offers full-time and part-time co...
# 13  Devmountain is a technology school that offers...
# 14  Ironhack offers 9-week, full-time and 24-week,...
# 15  Sabio is a developer community offering 12-wee...
# 16  Hackbright Academy is a software engineering s...
# 17  Le Wagon offers 9-week full-time and 24-week p...
# 18  Epicodus is a coding bootcamp offering part- a...
# 19  Coding Dojo is a unique coding bootcamp that t...
# 20  Lighthouse Labs is a Canadian bootcamp that te...
# 21  DevPoint Labs teaches 11-week full-time and 11...
# 22  Coder Academy is an accredited Australian codi...
# 23  Rithm School offers a full-time, 16-week, full...
# 24  The Grace Hopper Program is a 17-week, immersi...
# 25  LearningFuze offers a full immersion, 12-week ...
# 26  Coding Temple offers 10-week, full-stack codin...
# 27  Makers Academy is a highly selective 4-month, ...
# 28  Zip Code Wilmington offers two full-time, 12-w...
# 29  Eleven Fifty Academy is a non-profit coding an...
# 30  Launch Academy is a full-time, 18-week program...
# 31  SPICED Academy offers full-time, 12-week codin...
# 32  V School is a technology school in Provo and S...
# 33  Tech Talent South offers full and part-time pr...
# 34  Code Fellows offers full and part-time softwar...
# 35  Skill Distillery is an intensive, 16-week Java...
# 36  We Can Code IT is a full-stack software develo...
# 37  Actualize is a 12-week software development bo...
# 38  Code Platoon is a non-profit coding bootcamp l...
# 39  Prime Digital Academy offers an intensive, 20-...
# 40  Concordia Bootcamps offers a 12-week, full-tim...
# 41  Claim Academy is a 3-month developer coding an...
# 42  RED Academy is a full-time, 12-week or 24-week...
# 43  Coder Foundry is a North Carolina coding bootc...
# 44  The Tech Academy offers 5 full-time and part-t...
# 45  Juno College of Technology offers a 9-week, fu...
# 46  devCodeCamp delivers a choice of programs focu...
# 47  Skylab Coders Academy in Barcelona, Spain, off...

# %%
def get_rankings(url, bootcamp_type, date=datetime.date.today()):
    soup = get_suppe(url)
    school_list = get_school_list(soup)
    return pd.DataFrame([get_record(school, bootcamp_type, date) for school in school_list])

# %%
data_science_url = "https://www.coursereport.com/best-data-science-bootcamps"
get_rankings(data_science_url, "data-science")
# Out:
#        date_id bootcamp_type  rank                      name  rating  stars  \
# 0   2020-05-13  data-science     1              BrainStation    4.68    4.5
# 1   2020-05-13  data-science     2             Coding Temple    4.91    5.0
# 2   2020-05-13  data-science     3        Divergence Academy    5.00    5.0
# 3   2020-05-13  data-science     4           Flatiron School    4.71    4.5
# 4   2020-05-13  data-science     5                 Galvanize    4.47    4.5
# 5   2020-05-13  data-science     6          General Assembly    4.32    4.5
# 6   2020-05-13  data-science     7                     Metis    4.89    5.0
# 7   2020-05-13  data-science     8  NYC Data Science Academy    4.84    5.0
# 8   2020-05-13  data-science     9  Principal Analytics Prep    4.88    5.0
# 9   2020-05-13  data-science    10        Propulsion Academy    5.00    5.0
# 10  2020-05-13  data-science    11   Science to Data Science    4.95    5.0
# 11  2020-05-13  data-science    12            SPICED Academy    4.70    4.5
# 12  2020-05-13  data-science    13        The Data Incubator    4.79    4.5
# 13  2020-05-13  data-science    14                  Thinkful    4.59    4.5
# 14  2020-05-13  data-science    15       Ubiqum Code Academy    4.18    4.0
#
#     reviews                                          locations  \
# 0       352             Vancouver|Toronto|Online|New York City
# 1       120            Online|Washington|Boston|Chicago|Dallas
# 2        20                                             Dallas
# 3       439  Brooklyn|Online|Washington|Denver|Chicago|San ...
# 4       177  Los Angeles|Phoenix|Denver|San Francisco|Seatt...
# 5       452  Sydney|Singapore|Melbourne|London|Online|Detro...
# 6       105  Online|Chicago|San Francisco|Seattle|New York ...
# 7       288                               Online|New York City
# 8        17                                      New York City
# 9        54                                             Zurich
# 10       46                                      London|Online
# 11       57                             Hamburg|Cologne|Berlin
# 12       29  Online|Washington|Boston|San Francisco|New Yor...
# 13      572  Online|Detroit|Washington|Los Angeles|Phoenix|...
# 14       34                  Barcelona|Berlin|Amsterdam|Madrid
#
#                                           description
# 0   BrainStation offers full-time and part-time co...
# 1   Coding Temple offers 10-week, full-stack codin...
# 2   Divergence Academy is a 12-week full-time data...
# 3   Flatiron School offers immersive on-campus and...
# 4   Galvanize offers a 13-week full-time and a 26-...
# 5   General Assembly offers short and long courses...
# 6   Metis offers data science training via 12-week...
# 7   NYC Data Science Academy offers 12-week data s...
# 8   Principal Analytics Prep offers a 12-week, ful...
# 9   Propulsion Academy offers 12-week full-time bo...
# 10  Science to Data Science offers both a 5-week d...
# 11  SPICED Academy offers full-time, 12-week codin...
# 12  The Data Incubator offers an intensive full-ti...
# 13  Thinkful is an online bootcamp that equips stu...
# 14  Ubiqum Code Academy is an immersive, 4 to 5-mo...

# %%
list_of_bootcamps = ["coding", "data-science", "online"]

# %%
def get_rankings(bootcamp_type, date=datetime.date.today()):
    url = f"https://www.coursereport.com/best-{bootcamp_type}-bootcamps"
    soup = get_suppe(url)
    school_list = get_school_list(soup)
    return pd.DataFrame([get_record(school, bootcamp_type, date) for school in school_list])

# %%
coding, data_science, online = [get_rankings(bc) for bc in list_of_bootcamps]

# %% [markdown]
# # VII. Insert data into mysql
#
# (1) Create INSERT query

# %%
insert_query = "INSERT INTO coursereport.coding VALUES "
for idx, row in coding.iterrows():
    if idx != 0:
        insert_query = insert_query + ", "
        
    insert_query = insert_query + str((row["date_id"].strftime("%Y-%m-%d"),
                                       row["bootcamp_type"],
                                       row["rank"],
                                       row["name"],
                                       row["rating"],
                                       row["stars"],
                                       row["reviews"],
                                       row["locations"],
                                       row["description"]))

# %%
import pymysql
import getpass

# %%
pw = getpass.getpass()
conn = pymysql.connect(host="localhost",
                       port=3306,
                       user="ironhack",
                       passwd=pw)
# Out:
# ········

# %%
cursor = conn.cursor()

# %%
cursor.execute(insert_query)
# Out:
# 48

# %%
conn.commit()

# %%
conn.close()
